# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from scipy import integrate

# %%
A=1
f=1

# %%
w=2*np.pi*f

# %%
t = np.linspace(0, 1/f, 101)
a=A*np.sin(w*t)

# %%
np.sin(6.28*0.25)
# Out:
# 0.99999968293183461

# %%
t.shape
# Out:
# (101,)

# %%
a.shape
# Out:
# (101,)

# %%
v = integrate.cumtrapz(a,t,initial=0)

# %%
v.shape
# Out:
# (101,)

# %%
u= integrate.cumtrapz(v,t,initial=0)

# %%
u[-1]
# Out:
# 0.15910257976886985

# %%
plt.figure(figsize=(9,6))
plt.plot(t,a, 'b*-', label=u"a (m/s2)")
plt.plot(t,v, 'ro-', label=u"v (m/s)")
plt.plot(t,u, 'g--', label=u"u (m)")
plt.xlabel('t (s)')
plt.ylabel('m')
# plt.title('A title')
# add a legend with legend entries (because we didn't have labels when we plotted the data series)
plt.legend(['a', 'v', 'u'])
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
A=1
u_list_f=[]
u_list_max=[]
plt.figure(figsize=(9.8,15), dpi=100)
for i,f in enumerate ([1,2,3,4,5,6]):
    w=2*np.pi*f
    t = np.linspace(0, 1/f, 101)
    a=A*np.sin(w*t)
    v = integrate.cumtrapz(a,t,initial=0)
    u= integrate.cumtrapz(v,t,initial=0)
    u_list_f.append(u[-1])
    u_list_max.append(max(u))
    print ("last u =",u[-1],"when f=",f)
    plt.subplot(3,2,i+1)
    plt.plot(t,a, 'b*-', label=u"a (m/s2)")
    plt.plot(t,v, 'ro-', label=u"v (m/s)")
    plt.plot(t,u, 'g--', label=u"u (m)")
    plt.xlabel('t (s)')
    plt.ylabel('m')
    plt.legend(['a', 'v', 'u'])
    plt.title("f="+ str(f))
# Out:
# <img src="data:image/png;base64,..." width="980">
# last u = 0.159102579769 when f= 1
# last u = 0.0397756449422 when f= 2
# last u = 0.0176780644188 when f= 3
# last u = 0.00994391123555 when f= 4
# last u = 0.00636410319075 when f= 5
# last u = 0.00441951610469 when f= 6

# %%
A=1
u_list_f=[]
u_list_max=[]
plt.figure(figsize=(9.8,15), dpi=100)
for i,f in enumerate ([1,2,3,4,5,6]):
    w=2*np.pi*f
    t = np.linspace(0, 1, 101)
    a=A*np.sin(w*t)
    v = integrate.cumtrapz(a,t,initial=0)
    u= integrate.cumtrapz(v,t,initial=0)
    u_list_f.append(u[-1])
    u_list_max.append(max(u))
    print ("last u =",u[-1],"when f=",f)
    plt.subplot(3,2,i+1)
    #plt.plot(t,a, 'b*-', label=u"a (m/s2)")
    #plt.plot(t,v, 'ro-', label=u"v (m/s)")
    plt.plot(t,u, 'g--', label=u"u (m)")
    plt.xlabel('t (s)')
    plt.ylabel('m')
    plt.legend(['a', 'v', 'u'])
    plt.title("f="+ str(f))
# Out:
# <img src="data:image/png;base64,..." width="980">
# last u = 0.159102579769 when f= 1
# last u = 0.0794727242193 when f= 2
# last u = 0.052894474967 when f= 3
# last u = 0.0395790754415 when f= 4
# last u = 0.0315687575734 when f= 5
# last u = 0.0262109179056 when f= 6

# %%
plt.figure(figsize=(9,6))
plt.subplot(1,2,1)
plt.plot([1,2,3,4,5,6], u_list_f,'g-*')
plt.subplot(1,2,2)
plt.plot([1,2,3,4,5,6], u_list_max,'r-o')
plt.xlabel('f')
plt.ylabel('final u')
plt.title('relationship between f and final u')
# add a legend with legend entries (because we didn't have labels when we plotted the data series)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
A=1
u_list_f_all=[]
u_list_max_all=[]
av_list_all=[]
f_list=np.linspace(1,10,100)
for i,f in enumerate (f_list):
    w=2*np.pi*f
    t = np.linspace(0, 1/f, 101)
    a=A*np.sin(w*t)
    v = integrate.cumtrapz(a,t,initial=0)
    u= integrate.cumtrapz(v,t,initial=0)
    av=u[-1]*f
    u_list_f_all.append(u[-1])
    u_list_max_all.append(max(u))
    av_list_all.append(av)

# %%
u_list_f_all
# Out:
# [0.15910257976886985,
#  0.13369036216689756,
#  0.11391368137297779,
#  0.098221490571598222,
#  0.08556183178681448,
#  0.075200828718879884,
#  0.066613882879007796,
#  0.059417938740843335,
#  0.053328011501477118,
#  0.048128530380083148,
#  0.043653995809599201,
#  0.039775644942217463,
#  0.036392083463200865,
#  0.03342259054172439,
#  0.030802259443253214,
#  0.028478420343244448,
#  0.026407972773708158,
#  0.024555372642899555,
#  0.022891096494688758,
#  0.02139045794670362,
#  0.020032686942802549,
#  0.018800207179719971,
#  0.017678064418763292,
#  0.016653470719751949,
#  0.015715438491455715,
#  0.014854484685210832,
#  0.014062390176795643,
#  0.01333200287536928,
#  0.012657075708108647,
#  0.012032132595020785,
#  0.011452357020840714,
#  0.0109134989523998,
#  0.010411796729060705,
#  0.0099439112355543657,
#  0.0095068701985349374,
#  0.0090980208658002163,
#  0.0087149896568733485,
#  0.0083556476354310974,
#  0.0080180808629876088,
#  0.0077005648608133035,
# ...

# %%
plt.figure(figsize=(9,6))
plt.subplot(1,2,1)
plt.plot(f_list, u_list_f_all,'g-*')
plt.subplot(1,2,2)
plt.plot(f_list, u_list_max_all,'r-o')
plt.xlabel('f')
plt.ylabel('final u')
plt.title('relationship between f and final u')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
av_list_all
# Out:
# [0.15910257976886985,
#  0.14584403145479732,
#  0.1346252598044283,
#  0.12500916981839774,
#  0.11667522516383794,
#  0.10938302359109801,
#  0.10294872808573932,
#  0.097229354303198179,
#  0.09211201986618775,
#  0.087506418872878453,
#  0.083339446545598481,
#  0.079551289884434925,
#  0.076092538150329084,
#  0.072922015727398662,
#  0.070005135098302751,
#  0.067312629902214149,
#  0.064819569535465485,
#  0.062504584909198871,
#  0.06034925439508855,
#  0.058337612581918968,
#  0.056455754111534459,
#  0.054691511795549007,
#  0.053034193256289872,
#  0.051474364042869661,
#  0.050003667927359087,
#  0.048614677151599089,
#  0.047300766958312618,
#  0.046056009933093875,
#  0.044875086601476114,
#  0.043753209436439219,
#  0.042686057986769936,
#  0.04166972327279924,
#  0.040700659940873664,
#  0.039775644942217463,
#  0.038891741721279287,
#  0.038046269075164542,
#  0.037236773988458857,
#  0.036461007863699331,
#  0.035716905662399351,
#  0.035002567549151375,
# ...

# %%
plt.figure(figsize=(9,6))
plt.plot(f_list, av_list_all,'b-*')
plt.xlabel('f')
plt.ylabel('av')
plt.title('relationship between f and av')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
def func_av_f(f,a,b):
    return a*f-b*np.sin(1/f)

# %%
from scipy.optimize import curve_fit
popt, pcov = curve_fit(func_av_f, f_list, av_list_all)
#Optimal values for the parameters so that the sum of the squared residuals 
# of f(xdata, *popt) - ydata is minimized

# %%
print (popt)
# Out:
# [-0.0002884  -0.17275358]

# %%
plt.figure(figsize=(9,6))
plt.scatter(f_list,-0.0002884*f_list+0.17275358*np.sin(1/f_list),color="green")
plt.plot(f_list,func_av_f(f_list, *popt),color="red",label="fitting_curve: a=%5.7f, b=%5.7f" % tuple(popt))
plt.scatter(f_list,av_list_all,label="relation_av_to_f")
plt.xlabel('f')
plt.ylabel('av')
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
print ("av_f_fomular: av= -0.0002884*f+0.17275358*np.sin(1/f)")
# Out:
# av_f_fomular: av= -0.0002884*f+0.17275358*np.sin(1/f)

# %%
residuals = av_list_all- func_av_f(f_list, *popt)
ss_res = np.sum(residuals**2)
ss_tot = np.sum((av_list_all-np.mean(av_list_all))**2)
r_squared = 1 - (ss_res / ss_tot)
print (r_squared, "av_f_fitting_curve_R2")
# Out:
# 0.994172704126 av_f_fitting_curve_R2

# %%
f=1
u_list_A=[]
av_list_A=[]
plt.figure(figsize=(9.8,15), dpi=100)
for j,A in enumerate ([0.2,0.4,0.6,0.8,1]):
    w=2*np.pi*f
    t = np.linspace(0, 1/f, 101)
    a=A*np.sin(w*t)
    v = integrate.cumtrapz(a,t,initial=0)
    u= integrate.cumtrapz(v,t,initial=0)
    u_list_A.append(u[-1])
    av=u[-1]*f
    av_list_A.append(av)
    print ("last u =",u[-1],"when f=",f)
    plt.subplot(3,2,j+1)
    plt.plot(t,a, 'b*-', label=u"a (m/s2)")
    plt.plot(t,v, 'ro-', label=u"v (m/s)")
    plt.plot(t,u, 'g--', label=u"u (m)")
    plt.xlabel('t (s)')
    plt.ylabel('m')
    plt.legend(['a', 'v', 'u'])
    plt.title("A="+ str(A))
# Out:
# <img src="data:image/png;base64,..." width="980">
# last u = 0.0318205159538 when f= 1
# last u = 0.0636410319075 when f= 1
# last u = 0.0954615478613 when f= 1
# last u = 0.127282063815 when f= 1
# last u = 0.159102579769 when f= 1

# %%
plt.figure(figsize=(9,6))
plt.plot([0.2,0.4,0.6,0.8,1], u_list_A,'g*-')
plt.xlabel('A')
plt.ylabel('final u')
#plt.plot(x, intercept + slope*x, 'r', label='fitted line')
plt.title('relationship between A and final u')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress([0.2,0.4,0.6,0.8,1], u_list_A)
print (slope,intercept)
# Out:
# 0.159102579769 1.38777878078e-17

# %%
plt.figure(figsize=(9.8,50), dpi=100)
n=0
for j,A in enumerate ([0.2,0.4,0.6,0.8,1]):
    for i,f in enumerate ([1,2,3,4,5,6]):
        n+=1
        w=2*np.pi*f
        t = np.linspace(0, 1/f, 101)
        a=A*np.sin(w*t)
        v = integrate.cumtrapz(a,t,initial=0)
        u= integrate.cumtrapz(v,t,initial=0)
        u_list.append(u)
        print ("last u =",u[-1],"when f=",f, "when A=",A)
        plt.subplot(20,2,n+1)
        plt.plot(t,a, 'b*-', label=u"a (m/s2)")
        plt.plot(t,v, 'ro-', label=u"v (m/s)")
        plt.plot(t,u, 'g--', label=u"u (m)")
        plt.xlabel('t')
        plt.ylabel('m')
        plt.legend(['a', 'v', 'u'])
        plt.title("f="+ str(f)+" A="+str(A))
# Out:
# <img src="data:image/png;base64,..." width="980">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-b5e6a2be8b7c> in <module>()
#       9         v = integrate.cumtrapz(a,t,initial=0)
#      10         u= integrate.cumtrapz(v,t,initial=0)
# ---> 11         u_list.append(u)
#      12         print ("last u =",u[-1],"when f=",f, "when A=",A)
#      13         plt.subplot(20,2,n+1)
#
# NameError: name 'u_list' is not defined
