# %%
# %matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sympy as sp
from sympy import *

# %%
t = Symbol('t')

# %%
A=1
f=1
w=2*np.pi*f
a=A*sp.sin(w*t)

# %%
v=integrate(a, t)
v

# %%
v
# Out:
# -0.159154943091895*cos(6.28318530717959*t)

# %%
v_positive=(-0.159154943091895*cos(6.28318530717959*t))+0.159154943091895

# %%
u=integrate(v,t)

# %%
u
# Out:
# -0.0253302959105844*sin(6.28318530717959*t)

# %%
u_positive=integrate(v_positive,t)
u_positive
# Out:
# 0.159154943091895*t - 0.0253302959105844*sin(6.28318530717959*t)

# %%
a_array=A*np.sin(w*t_array)

# %%
t_array=np.linspace(0, 1/f, 101)
t_array.shape
# Out:
# (101,)

# %%
t_array.dtype
# Out:
# dtype('float64')

# %%
v_array=-0.159154943091895*np.cos(6.28318530717959*t_array)

# %%
v_array_positive=-0.159154943091895*np.cos(6.28318530717959*t_array)+0.159154943091895

# %%
v_array
# Out:
# array([ -1.59154943e-01,  -1.58840887e-01,  -1.57899959e-01,
#         -1.56335871e-01,  -1.54154798e-01,  -1.51365346e-01,
#         -1.47978524e-01,  -1.44007698e-01,  -1.39468540e-01,
#         -1.34378963e-01,  -1.28759054e-01,  -1.22630991e-01,
#         -1.16018960e-01,  -1.08949056e-01,  -1.01449179e-01,
#         -9.35489284e-02,  -8.52794831e-02,  -7.66734786e-02,
#         -6.77648789e-02,  -5.85888422e-02,  -4.91815822e-02,
#         -3.95802248e-02,  -2.98226625e-02,  -1.99474037e-02,
#         -9.99342156e-03,   1.31612556e-16,   9.99342156e-03,
#          1.99474037e-02,   2.98226625e-02,   3.95802248e-02,
#          4.91815822e-02,   5.85888422e-02,   6.77648789e-02,
#          7.66734786e-02,   8.52794831e-02,   9.35489284e-02,
#          1.01449179e-01,   1.08949056e-01,   1.16018960e-01,
#          1.22630991e-01,   1.28759054e-01,   1.34378963e-01,
#          1.39468540e-01,   1.44007698e-01,   1.47978524e-01,
# ...

# %%
u_array=-0.0253302959105844*np.sin(6.28318530717959*t_array)

# %%
u_array_positive=0.159154943091895*t_array - 0.0253302959105844*np.sin(6.28318530717959*t_array)

# %%
plt.figure(figsize=(9,6))
plt.plot(t_array,a_array, 'b*-', label=u"a (m/s2)")
plt.plot(t_array,v_array, 'ro-', label=u"v (m/s)")
plt.plot(t_array,u_array, 'g--', label=u"u (m)")
plt.xlabel('t (s)')
plt.ylabel('m')
# plt.title('A title')
# add a legend with legend entries (because we didn't have labels when we plotted the data series)
plt.legend(['a', 'v', 'u'])
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
plt.figure(figsize=(9,6))
plt.plot(t_array,a_array, 'b*-', label=u"a (m/s2)")
plt.plot(t_array,v_array_positive, 'ro-', label=u"v (m/s)")
plt.plot(t_array,u_array_positive, 'g--', label=u"u (m)")
plt.xlabel('t (s)')
plt.ylabel('m')
# plt.title('A title')
# add a legend with legend entries (because we didn't have labels when we plotted the data series)
plt.legend(['a', 'v', 'u'])
print (u_array_positive[-1])
# Out:
# <img src="data:image/png;base64,..." width="900">
# 0.159154943092

# %%
from scipy import integrate

# %%
A=1
f=1
w=2*np.pi*f

# %%
a=lambda t:A*np.sin(w*t)

# %%
integrate.quad(a,0,1)
# Out:
# (-1.1372737176807543e-17, 7.002641250699693e-15)

# %%
from sympy.abc import A

# %%
f=1

# %%
v_f=integrate(A*sp.sin(2*np.pi*f*t), t)
v_f
# Out:
# -0.159154943091895*A*cos(6.28318530717959*t)

# %%
v_f=(-0.159154943091895*A*cos(6.28318530717959*t))+0.16*A*t

# %%
u_f=integrate(v_f,t)
u_f
# Out:
# 0.08*A*t**2 - 0.0253302959105844*A*sin(6.28318530717959*t)

# %%
# 0.159154943091895*t - 0.0253302959105844*sin(6.28318530717959*t)

# %%
u_f=-0.0253302959105844*sin(6.28318530717959*t*x)/x

# %%
plt.figure(figsize=(9.8,15), dpi=100)
for i,x in enumerate ([1,2,3,4,5,6]):
    w=2*np.pi*x
    t_array = np.linspace(0, 1/x, 101)
    a_f_array=A*np.sin(w*t_array)
    v_f_array = -0.159154943091895*np.cos(6.28318530717959*t_array*x)/x
    u_f_array = - 0.0253302959105844*(np.sin(6.28318530717959*t_array*x)/x)
    plt.subplot(3,2,i+1)
    plt.plot(t_array,a_f_array, 'b*-', label=u"a (m/s2)")
    plt.plot(t_array,v_f_array, 'ro-', label=u"v (m/s)")
    plt.plot(t_array,u_f_array, 'g--', label=u"u (m)")
    plt.xlabel('t (s)')
    plt.ylabel('m')
    plt.legend(['a', 'v', 'u'])
    plt.title("f="+ str(f))
# Out:
# <img src="data:image/png;base64,..." width="980">
